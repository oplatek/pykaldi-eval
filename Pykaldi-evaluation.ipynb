# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['rec']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
import pickle
import pylab as pl
from collections import namedtuple

def cwer(ins, dl, sub, refer_words):
    return float((ins + dl + sub)) / refer_words

# Measured for 50 wav utterances at once
SysRecord = namedtuple('SysRecord', 
                       ['wav_scp', 'beam', 'lattice_beam', 'max_active', 'wavlen',
                        'decodelen', 'forwardlen', 'backwardlen', 'refer_words', 'ins', 'dl', 'sub', 'ser'])

# Measured for every single wav utterances (50 utterances)
UserRecord = namedtuple('UserRecord', 
                        ['wav_name', 'wav_len', 'beam', 'lattice_beam', 'max_active', 'forwardlen', 'backwardlen'])


# with open('./records4_pickled.log', 'r') as r:
with open('./k53s_wer16_lb_b_max_picked.txt', 'r') as r:
    sys_time_r = pickle.load(r)
    user_time_r = pickle.load(r)
    


beam_range = sorted(list(set([rec.beam for rec in sys_time_r])))
lat_beam_range = sorted(list(set([rec.lattice_beam for rec in user_time_r])))
max_active_range = sorted(list(set([rec.max_active for rec in user_time_r])))
# list of wav length values for particular fixed setup (all setups use the same wavs).
wav_len_values = sorted([urec.wav_len for urec in user_time_r if 
                         urec.max_active==max_active_range[0] and urec.lattice_beam==lat_beam_range[0] and urec.beam==beam_range[0]])

# %%
werv =[ (cwer(rec.ins, rec.dl, rec.sub, rec.refer_words), rec.beam, rec.lattice_beam, rec.max_active) for rec in sys_time_r]

print sorted([(l,b,m,w) for (w,b,l,m) in werv])
# Out:
# [(7.0, 13.0, 2000.0, 0.1953125), (7.0, 13.0, 6000.0, 0.18110795454545456), (7.0, 13.0, 12000.0, 0.1807528409090909), (7.0, 14.0, 2000.0, 0.19673295454545456), (7.0, 14.0, 6000.0, 0.1825284090909091), (7.0, 14.0, 12000.0, 0.18110795454545456), (7.0, 15.0, 2000.0, 0.1963778409090909), (7.0, 15.0, 6000.0, 0.1825284090909091), (7.0, 15.0, 12000.0, 0.18110795454545456), (7.0, 16.0, 2000.0, 0.1963778409090909), (7.0, 16.0, 6000.0, 0.1825284090909091), (7.0, 16.0, 12000.0, 0.18110795454545456), (7.0, 16.5, 2000.0, 0.19673295454545456), (7.0, 16.5, 6000.0, 0.18217329545454544), (7.0, 16.5, 12000.0, 0.1807528409090909), (7.5, 13.0, 2000.0, 0.19566761363636365), (7.5, 13.0, 6000.0, 0.18110795454545456), (7.5, 13.0, 12000.0, 0.1807528409090909), (7.5, 14.0, 2000.0, 0.19708806818181818), (7.5, 14.0, 6000.0, 0.1825284090909091), (7.5, 14.0, 12000.0, 0.18110795454545456), (7.5, 15.0, 2000.0, 0.19673295454545456), (7.5, 15.0, 6000.0, 0.1825284090909091), (7.5, 15.0, 12000.0, 0.18110795454545456), (7.5, 16.0, 2000.0, 0.19673295454545456), (7.5, 16.0, 6000.0, 0.1825284090909091), (7.5, 16.0, 12000.0, 0.18110795454545456), (7.5, 16.5, 2000.0, 0.19708806818181818), (7.5, 16.5, 6000.0, 0.18217329545454544), (7.5, 16.5, 12000.0, 0.1807528409090909), (8.0, 13.0, 2000.0, 0.19566761363636365), (8.0, 13.0, 12000.0, 0.1807528409090909), (8.0, 14.0, 2000.0, 0.19708806818181818), (8.0, 14.0, 6000.0, 0.1825284090909091), (8.0, 14.0, 12000.0, 0.18217329545454544), (8.0, 15.0, 2000.0, 0.19673295454545456), (8.0, 15.0, 6000.0, 0.1825284090909091), (8.0, 15.0, 12000.0, 0.18217329545454544), (8.0, 16.0, 2000.0, 0.19673295454545456), (8.0, 16.0, 6000.0, 0.1825284090909091), (8.0, 16.0, 12000.0, 0.18217329545454544), (8.0, 16.5, 2000.0, 0.19708806818181818), (8.0, 16.5, 6000.0, 0.18217329545454544), (8.0, 16.5, 12000.0, 0.18181818181818182), (9.5, 13.0, 2000.0, 0.19566761363636365), (9.5, 13.0, 6000.0, 0.18110795454545456), (9.5, 13.0, 12000.0, 0.1807528409090909), (9.5, 14.0, 2000.0, 0.19708806818181818), (9.5, 14.0, 6000.0, 0.1825284090909091), (9.5, 14.0, 12000.0, 0.18217329545454544), (9.5, 15.0, 2000.0, 0.19673295454545456), (9.5, 15.0, 6000.0, 0.1825284090909091), (9.5, 15.0, 12000.0, 0.18217329545454544), (9.5, 16.0, 2000.0, 0.19673295454545456), (9.5, 16.0, 6000.0, 0.19673295454545456), (9.5, 16.0, 12000.0, 0.19673295454545456), (9.5, 16.5, 2000.0, 0.19673295454545456), (9.5, 16.5, 6000.0, 0.19673295454545456), (9.5, 16.5, 12000.0, 0.19673295454545456), (11.5, 13.0, 2000.0, 0.19673295454545456), (11.5, 13.0, 6000.0, 0.19673295454545456), (11.5, 13.0, 12000.0, 0.19673295454545456), (11.5, 14.0, 2000.0, 0.19673295454545456), (11.5, 14.0, 6000.0, 0.19673295454545456), (11.5, 14.0, 12000.0, 0.19673295454545456), (11.5, 15.0, 2000.0, 0.19673295454545456), (11.5, 15.0, 6000.0, 0.19673295454545456), (11.5, 15.0, 12000.0, 0.19673295454545456), (11.5, 16.0, 2000.0, 0.19673295454545456), (11.5, 16.0, 6000.0, 0.19673295454545456), (11.5, 16.0, 12000.0, 0.19673295454545456), (11.5, 16.5, 2000.0, 0.19673295454545456), (11.5, 16.5, 6000.0, 0.19673295454545456), (11.5, 16.5, 12000.0, 0.19673295454545456)]

# %% [markdown]
# TODO graphs
# ===========
#
#  * x axes: state-level beam, f1(x) == WER, f2(x) == RTF
#  * x axes: lattice-beam, f1(x) == WER, f2(x) == latency
#  * x axes: wav-length, f(x) = latency
#  * x axes: percentil for wav recordings, f1(x) == RTF, f2(x) == 1.0 - teoretical acceptible treshold RTF, f3(x) == 0.6 - practical stricter treshold
#  * x axes: percentil for wav recordings, f1(x) == latency, f2(x) == 0.4s - acceptabel latency treshold
#  * For Google: x axes: percentil for wav recordings, f1(x) == latency, f2(x) == 0.4s - acceptabel latency treshold

# %%
print('Number of wavs %d. Min length %f, Max length %f, Avg length %f' % (len(wav_len_values), min(wav_len_values), max(wav_len_values), sum(wav_len_values) / len(wav_len_values))) 
pl.plot(wav_len_values,'+')
pl.show()
pl.bar(range(len(beam_range)), beam_range)
pl.show()
print beam_range
# Out:
# Number of wavs 948. Min length 0.400000, Max length 59.808000, Avg length 2.128068
# [13.0, 14.0, 15.0, 16.0, 16.5]

# %%
lat_beam, max_active = lat_beam_range[2], max_active_range[2]
minf, avgf, maxf, werl = [], [], [], []
for beam in beam_range:
    forwardrtf = [ rec.forwardlen / float(rec.wav_len) for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    wers = [ cwer(rec.ins, rec.dl, rec.sub, rec.refer_words) for rec in sys_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    assert len(wers) == 1, 'wer is computed for each setting on all utterances at once-> 1 value'
    werl.append(wers[0])
    minf.append(min(forwardrtf))
    avgf.append(sum(forwardrtf) / float(len(forwardrtf)))
    maxf.append(max(forwardlen))
werl = [100.0 * w for w in werl]  # TODO DEBUG add scale for wer
#pl.plot(beam_range, werl, 'y')
pl.plot(beam_range, minf, 'g')
pl.plot(beam_range, avgf, 'b')
pl.plot(beam_range, [1.0] * len(beam_range), 'r')
#pl.plot(beam_range, maxf, 'r')
pl.show()

# %%
beam, max_active = beam_range[2], max_active_range[0]
minb, avgb, maxb, werl = [], [], [], []
for lat_beam in lat_beam_range:
    backwardlen = [ rec.backwardlen for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    wers = [ cwer(rec.ins, rec.dl, rec.sub, rec.refer_words) for rec in sys_time_r if rec.beam == beam and rec.lattice_beam == lat_beam and rec.max_active == max_active]
    assert len(wers) == 1, 'wer is computed for each setting on all utterances at once-> 1 value'
    werl.append(wers[0])
    minb.append(min(backwardlen))
    avgb.append(sum(backwardlen) / float(len(forwardlen)))
    maxb.append(max(backwardlen))
werl = [100.0 * w for w in werl]  # TODO DEBUG add scale for wer
print werl
#pl.plot(lat_beam_range, werl, 'y')
pl.plot(lat_beam_range, minb, 'g')
pl.plot(lat_beam_range, avgb, 'b')
pl.plot(lat_beam_range, [0.4] * len(lat_beam_range), 'r')
# pl.plot(lat_beam_range, maxb, 'r')
pl.show()
# Out:
# [19.63778409090909, 19.673295454545457, 19.673295454545457, 19.673295454545457]

# %%
lat_beam, max_active = lat_beam_range[2], max_active_range[0]
minb, avgb, maxb = [], [], []
for beam in beam_range:
    backwardlen = [ rec.backwardlen for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    minb.append(min(backwardlen))
    avgb.append(sum(backwardlen) / float(len(forwardlen)))
    maxb.append(max(backwardlen))
pl.plot(beam_range, minb, 'g')
pl.plot(beam_range, avgb, 'b')
# pl.plot(beam_range, maxb, 'r')
pl.show()

# %%
beam, max_active = beam_range[2], max_active_range[0]
minf, avgf, maxf = [], [], []
for lat_beam in lat_beam_range:
    forwardrtf = [ rec.forwardlen/ float(rec.wav_len) for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    minf.append(min(forwardrtf))
    avgf.append(sum(forwardrtf) / float(len(forwardrtf)))
    maxf.append(max(forwardrtf))
pl.plot(lat_beam_range, minf, 'g')
pl.plot(lat_beam_range, avgf, 'b')
pl.plot(lat_beam_range, maxf, 'r')
pl.show()
