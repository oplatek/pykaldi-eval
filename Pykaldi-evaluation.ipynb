# %% [markdown]
# Pykaldi GmmLatgenWrapper evaluation
# ===================================
#
# *GmmLatgenWrapper* is a minimalistic extension to Kaldi toolkit,
# supporting real time decoding.
#
# We use it through its *PyGmmLatgenWrapper* Python wrapper.
# Both developed at pykaldi git repository:
#
# https://github.com/UFAL-DSG/pykaldi
#
# The evaluation scripts are also available online:
#
# https://github.com/oplatek/pykaldi-eval

# %% [markdown]
# Loading data and extracting basic information
# =============================================

# %%
# %pylab inline
import pickle
import pylab as pl
from collections import namedtuple

def cwer(ins, dl, sub, refer_words):
    return (100.0 * (ins + dl + sub)) / refer_words

# Measured for 50 wav utterances at once
SysRecord = namedtuple('SysRecord', 
                       ['wav_scp', 'beam', 'lattice_beam', 'max_active', 'wavlen',
                        'decodelen', 'forwardlen', 'backwardlen', 'refer_words', 'ins', 'dl', 'sub', 'ser'])

# Measured for every single wav utterances (50 utterances)
UserRecord = namedtuple('UserRecord', 
                        ['wav_name', 'wav_len', 'beam', 'lattice_beam', 'max_active', 'forwardlen', 'backwardlen'])


with open('./all_5931_few_test_30_new_kaldi.pickle.log', 'r') as r:
    sys_time_r = pickle.load(r)
    user_time_r = pickle.load(r)
    


beam_range = sorted(list(set([rec.beam for rec in sys_time_r])))
lat_beam_range = sorted(list(set([rec.lattice_beam for rec in user_time_r])))
max_active_range = sorted(list(set([rec.max_active for rec in user_time_r])))
# list of wav length values for particular fixed setup (all setups use the same wavs).
wav_len_values = sorted([urec.wav_len for urec in user_time_r if 
                         urec.max_active==max_active_range[0] and urec.lattice_beam==lat_beam_range[0] and urec.beam==beam_range[0]])

# Check
wl_dup, bt, beam, lat_beam, max_active = [], [], beam_range[0], lat_beam_range[0], max_active_range[0]
wav_name_len, exp_num_conf = len([rec.wav_name for rec in user_time_r]), len(beam_range) * len(lat_beam_range) * len(max_active_range)
print 'Checking if integer: We used %0.1f wave files in wav.scp' % (wav_name_len / float(exp_num_conf))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Checking if integer: We used 10.0 wave files in wav.scp
# WARNING: pylab import has clobbered these variables: ['rec']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %% [markdown]
# Explore parameters
# ------------------

# %%
print('Number of wavs %d. Min length %f, Max length %f, Avg length %f' % (len(wav_len_values), min(wav_len_values), max(wav_len_values), sum(wav_len_values) / len(wav_len_values))) 

subplot(1,3,1)
plot(range(len(wav_len_values)), wav_len_values, '+')
ylabel('wav len')
xlabel('wav index')
title('Wave lengths')

subplot(1,3,2)
ylabel('beam values')
title('Forward beam')
bar(range(len(beam_range)), beam_range)
frame = gca()
frame.axes.get_xaxis().set_visible(False)

subplot(1,3,3)
title('Lattice beam values')
ylabel('lattice-beam')
bar(range(len(lat_beam_range)), lat_beam_range)
frame = gca()
frame.axes.get_xaxis().set_visible(False)

tight_layout()
# Out:
# Number of wavs 10. Min length 0.896000, Max length 4.368000, Avg length 2.113600

# %% [markdown]
# Graphs for the paper
# ====================

# %%
beam, lat_beam, max_active = beam_range[3], lat_beam_range[4], max_active_range[1]
rtf = sorted([ rec.forwardlen / float(rec.wav_len) for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam and rec.max_active == max_active])
rtf_95 = rtf[0:int(0.95*len(rtf))]
percents = [float(x) / len(rtf) for x in range(1,len(rtf)+1,1)]
percents_95 = percents[0:int(0.95*len(percents))]

#subplot(2,1,1)
#ylim([0, 1.1])
#plot(percents_95, rtf_95, '.-.')
#title('(b: %0.1f, lb: %0.1f, ma: %d) Forward RTF decoding vs percentil (0, 0.95)'% (beam, lat_beam, max_active))
#ylabel('Forward RTF')
#plot(percents_95, [0.6] * len(percents_95), 'g--')
#plot(percents_95, [1.0] * len(percents_95), 'r--')

# subplot(2,1,2)
ylim([0, 1.1])
plot(percents, rtf, '.-.')
title('Forward RTF decoding vs percentil, marked 0.95 percentil')
ylabel('Backward decoding time')
plot(percents, [0.6] * len(percents), 'g--')
plot(percents, [1.0] * len(percents), 'r--')
axvline(0.95, color='g')
tight_layout()

# %%
beam, lat_beam, max_active = beam_range[3], lat_beam_range[4], max_active_range[1]
bt = sorted([ rec.backwardlen for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam and rec.max_active == max_active])
bt_95 = bt[0:int(0.95*len(bt))]
percents = [float(x) / len(bt) for x in range(1,len(bt)+1,1)]
percents_95 = percents[0:int(0.95*len(percents))]

subplot(2,1,1)
ylim([0, 1.0])
plot(percents_95, bt_95,'.-.')
title('(b: %0.1f, lb: %0.1f, ma: %d) Backward decoding vs percentil' % (beam, lat_beam, max_active))
ylabel('Backward decoding time')
plot(percents_95, [0.4] * len(percents_95), 'r--')

subplot(2,1,2)
ylim([0, 1.0])
plot(percents, bt,'.-.')
title('Backward decoding vs percentil, marked 0.95 percentil')
ylabel('Backward decoding time')
plot(percents, [0.4] * len(percents), 'r--')
axvline(0.95, color='g')
tight_layout()

# %%
wl_dup, bt, beam, lat_beam, max_active = [], [], beam_range[4], lat_beam_range[4], max_active_range[1]

for wl in wav_len_values:
    back_time = [ rec.backwardlen for rec in user_time_r if 
                 rec.beam == beam and rec.wav_len == wl and
                 rec.lattice_beam == lat_beam and rec.max_active == max_active]
    for btv in back_time:
        wl_dup.append(wl)
        bt.append(btv)
    
plot(wl_dup, bt, '.')    
xlabel('wav len')
ylabel('Backward decoding time ~ Latency')
title('(b: %0.1f, lb: %0.1f, ma: %d) Latency vs wave length.' % (beam, lat_beam, max_active))

# %%
lat_beam, max_active = lat_beam_range[4], max_active_range[1]
minf, avgf, maxf, werl = [], [], [], []
for beam in beam_range:
    forwardrtf = [ rec.forwardlen / float(rec.wav_len) for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    wers = [ cwer(rec.ins, rec.dl, rec.sub, rec.refer_words) for rec in sys_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    assert len(wers) == 1, 'wer is computed for each setting on all utterances at once-> 1 value'
    werl.append(wers[0])
    minf.append(min(forwardrtf))
    avgf.append(sum(forwardrtf) / float(len(forwardrtf)))
    maxf.append(max(forwardrtf))

fig, ax1 = subplots()
ax1.plot(beam_range, minf, 'g.-.')
ax1.plot(beam_range, avgf, 'b.-.')
ax1.plot(beam_range, [1.0] * len(beam_range), 'b--')
ax1.plot(beam_range, [0.6] * len(beam_range), 'b--')
ax1.plot(beam_range, maxf, 'r.-.')
ax1.set_xlabel('Beam values')
ax1.set_ylabel('Forward RTF')
for tl in ax1.get_yticklabels():
    tl.set_color('b')

ax2 = ax1.twinx()
ax2.plot(beam_range, werl, 'y')
ax2.set_ylabel('WER')
ylim([0, 110])
for tl in ax2.get_yticklabels():
    tl.set_color('y')

title('(lb: %0.1f, ma: %d )Forward beam vs forward RTF and WER (TODO: 95 values instead of min, max, avg.)' % (lat_beam, max_active))

# %%
beam, max_active = beam_range[0], max_active_range[0]
minf, avgf, maxf, werl = [], [], [], []
for lat_beam in lat_beam_range:
    back_time = [ rec.backwardlen for rec in user_time_r if rec.beam == beam 
                 and rec.lattice_beam == lat_beam and rec.max_active == max_active]
    wers = [ cwer(rec.ins, rec.dl, rec.sub, rec.refer_words) for rec in sys_time_r if rec.beam == beam 
            and rec.lattice_beam == lat_beam and rec.max_active == max_active]
    assert len(wers) == 1, 'wer is computed for each setting on all utterances at once-> 1 value'
    werl.append(wers[0])
    minf.append(min(back_time))
    avgf.append(sum(back_time) / float(len(back_time)))
    maxf.append(max(back_time))

fig, ax1 = subplots()
ax1.plot(lat_beam_range, minf, 'g.-.')
ax1.plot(lat_beam_range, avgf, 'b.-.')
ax1.plot(lat_beam_range, [0.4] * len(lat_beam_range), 'b--')
ax1.plot(lat_beam_range, maxf, 'r.-.')
ax1.set_xlabel('Lattice beam values')
ax1.set_ylabel('Backward decoding time ~ Latency')
for tl in ax1.get_yticklabels():
    tl.set_color('b')

ax2 = ax1.twinx()
ax2.plot(lat_beam_range, werl, 'y')
ylim([0, 110])
ax2.set_ylabel('WER')
for tl in ax2.get_yticklabels():
    tl.set_color('y')

title('Backward lat_beam vs latency and WER (TODO: 95% values instead of min, max, avg.)')

# %% [markdown]
# Additional and debugging graphs
# ===============================

# %%
lat_beam, max_active = lat_beam_range[0], max_active_range[0]
minb, avgb, maxb = [], [], []
for beam in beam_range:
    backwardlen = [ rec.backwardlen for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    minb.append(min(backwardlen))
    avgb.append(sum(backwardlen) / float(len(backwardlen)))
    maxb.append(max(backwardlen))
pl.plot(beam_range, minb, 'g')
pl.plot(beam_range, avgb, 'b')
# pl.plot(beam_range, maxb, 'r')
pl.show()

# %%
beam, max_active = beam_range[2], max_active_range[0]
minf, avgf, maxf = [], [], []
for lat_beam in lat_beam_range:
    forwardrtf = [ rec.forwardlen/ float(rec.wav_len) for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    minf.append(min(forwardrtf))
    avgf.append(sum(forwardrtf) / float(len(forwardrtf)))
    maxf.append(max(forwardrtf))
pl.plot(lat_beam_range, minf, 'g')
pl.plot(lat_beam_range, avgf, 'b')
pl.plot(lat_beam_range, maxf, 'r')
pl.show()

# %%
werv =[ (cwer(rec.ins, rec.dl, rec.sub, rec.refer_words), rec.beam, rec.lattice_beam, rec.max_active) for rec in sys_time_r]

print sorted([(l,b,m,w) for (w,b,l,m) in werv])
# Out:
# [(1.0, 8.0, 2000.0, 4.878048780487805), (1.0, 8.0, 5000.0, 4.878048780487805), (1.0, 8.0, 8000.0, 4.878048780487805), (1.0, 9.0, 2000.0, 4.878048780487805), (1.0, 9.0, 5000.0, 4.878048780487805), (1.0, 9.0, 8000.0, 4.878048780487805), (1.0, 10.0, 2000.0, 4.878048780487805), (1.0, 10.0, 5000.0, 4.878048780487805), (1.0, 10.0, 8000.0, 4.878048780487805), (1.0, 11.0, 2000.0, 4.878048780487805), (1.0, 11.0, 5000.0, 4.878048780487805), (1.0, 11.0, 8000.0, 4.878048780487805), (1.0, 12.0, 2000.0, 4.878048780487805), (1.0, 12.0, 5000.0, 4.878048780487805), (1.0, 12.0, 8000.0, 4.878048780487805), (1.0, 13.0, 2000.0, 4.878048780487805), (1.0, 13.0, 5000.0, 4.878048780487805), (1.0, 13.0, 8000.0, 4.878048780487805), (1.0, 16.0, 2000.0, 4.878048780487805), (1.0, 16.0, 5000.0, 4.878048780487805), (1.0, 16.0, 8000.0, 4.878048780487805), (2.0, 8.0, 2000.0, 4.878048780487805), (2.0, 8.0, 5000.0, 4.878048780487805), (2.0, 8.0, 8000.0, 4.878048780487805), (2.0, 9.0, 2000.0, 4.878048780487805), (2.0, 9.0, 5000.0, 4.878048780487805), (2.0, 9.0, 8000.0, 4.878048780487805), (2.0, 10.0, 2000.0, 4.878048780487805), (2.0, 10.0, 5000.0, 4.878048780487805), (2.0, 10.0, 8000.0, 4.878048780487805), (2.0, 11.0, 2000.0, 4.878048780487805), (2.0, 11.0, 5000.0, 4.878048780487805), (2.0, 11.0, 8000.0, 4.878048780487805), (2.0, 12.0, 2000.0, 4.878048780487805), (2.0, 12.0, 5000.0, 4.878048780487805), (2.0, 12.0, 8000.0, 4.878048780487805), (2.0, 13.0, 2000.0, 4.878048780487805), (2.0, 13.0, 5000.0, 4.878048780487805), (2.0, 13.0, 8000.0, 4.878048780487805), (2.0, 16.0, 2000.0, 4.878048780487805), (2.0, 16.0, 5000.0, 4.878048780487805), (2.0, 16.0, 8000.0, 4.878048780487805), (3.0, 8.0, 2000.0, 4.878048780487805), (3.0, 8.0, 5000.0, 4.878048780487805), (3.0, 8.0, 8000.0, 4.878048780487805), (3.0, 9.0, 2000.0, 4.878048780487805), (3.0, 9.0, 5000.0, 4.878048780487805), (3.0, 9.0, 8000.0, 4.878048780487805), (3.0, 10.0, 2000.0, 4.878048780487805), (3.0, 10.0, 5000.0, 4.878048780487805), (3.0, 10.0, 8000.0, 4.878048780487805), (3.0, 11.0, 2000.0, 4.878048780487805), (3.0, 11.0, 5000.0, 4.878048780487805), (3.0, 11.0, 8000.0, 4.878048780487805), (3.0, 12.0, 2000.0, 4.878048780487805), (3.0, 12.0, 5000.0, 4.878048780487805), (3.0, 12.0, 8000.0, 4.878048780487805), (3.0, 13.0, 2000.0, 4.878048780487805), (3.0, 13.0, 5000.0, 4.878048780487805), (3.0, 13.0, 8000.0, 4.878048780487805), (3.0, 16.0, 2000.0, 4.878048780487805), (3.0, 16.0, 5000.0, 4.878048780487805), (3.0, 16.0, 8000.0, 4.878048780487805), (4.0, 8.0, 2000.0, 4.878048780487805), (4.0, 8.0, 5000.0, 4.878048780487805), (4.0, 8.0, 8000.0, 4.878048780487805), (4.0, 9.0, 2000.0, 4.878048780487805), (4.0, 9.0, 5000.0, 4.878048780487805), (4.0, 9.0, 8000.0, 4.878048780487805), (4.0, 10.0, 2000.0, 4.878048780487805), (4.0, 10.0, 5000.0, 4.878048780487805), (4.0, 10.0, 8000.0, 4.878048780487805), (4.0, 11.0, 2000.0, 4.878048780487805), (4.0, 11.0, 5000.0, 4.878048780487805), (4.0, 11.0, 8000.0, 4.878048780487805), (4.0, 12.0, 2000.0, 4.878048780487805), (4.0, 12.0, 5000.0, 4.878048780487805), (4.0, 12.0, 8000.0, 4.878048780487805), (4.0, 13.0, 2000.0, 4.878048780487805), (4.0, 13.0, 5000.0, 4.878048780487805), (4.0, 13.0, 8000.0, 4.878048780487805), (4.0, 16.0, 2000.0, 4.878048780487805), (4.0, 16.0, 5000.0, 4.878048780487805), (4.0, 16.0, 8000.0, 4.878048780487805), (5.0, 8.0, 2000.0, 4.878048780487805), (5.0, 8.0, 5000.0, 4.878048780487805), (5.0, 8.0, 8000.0, 4.878048780487805), (5.0, 9.0, 2000.0, 4.878048780487805), (5.0, 9.0, 5000.0, 4.878048780487805), (5.0, 9.0, 8000.0, 4.878048780487805), (5.0, 10.0, 2000.0, 4.878048780487805), (5.0, 10.0, 5000.0, 4.878048780487805), (5.0, 10.0, 8000.0, 4.878048780487805), (5.0, 11.0, 2000.0, 4.878048780487805), (5.0, 11.0, 5000.0, 4.878048780487805), (5.0, 11.0, 8000.0, 4.878048780487805), (5.0, 12.0, 2000.0, 4.878048780487805), (5.0, 12.0, 5000.0, 4.878048780487805), (5.0, 12.0, 8000.0, 4.878048780487805), (5.0, 13.0, 2000.0, 4.878048780487805), (5.0, 13.0, 5000.0, 4.8780487 ...
