# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['rec']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
import pickle
import pylab as pl
from collections import namedtuple

def cwer(ins, dl, sub, refer_words):
    return (100.0 * (ins + dl + sub)) / refer_words

# Measured for 50 wav utterances at once
SysRecord = namedtuple('SysRecord', 
                       ['wav_scp', 'beam', 'lattice_beam', 'max_active', 'wavlen',
                        'decodelen', 'forwardlen', 'backwardlen', 'refer_words', 'ins', 'dl', 'sub', 'ser'])

# Measured for every single wav utterances (50 utterances)
UserRecord = namedtuple('UserRecord', 
                        ['wav_name', 'wav_len', 'beam', 'lattice_beam', 'max_active', 'forwardlen', 'backwardlen'])


with open('./test_16_wer_collect.pickle.txt', 'r') as r:
    sys_time_r = pickle.load(r)
    user_time_r = pickle.load(r)
    


beam_range = sorted(list(set([rec.beam for rec in sys_time_r])))
lat_beam_range = sorted(list(set([rec.lattice_beam for rec in user_time_r])))
max_active_range = sorted(list(set([rec.max_active for rec in user_time_r])))
# list of wav length values for particular fixed setup (all setups use the same wavs).
wav_len_values = sorted([urec.wav_len for urec in user_time_r if 
                         urec.max_active==max_active_range[0] and urec.lattice_beam==lat_beam_range[0] and urec.beam==beam_range[0]])

# %% [markdown]
# TODO graphs
# ===========
#
#  * x axes: state-level beam, f1(x) == WER, f2(x) == RTF (ALMOST DONE)
#  * x axes: lattice-beam, f1(x) == WER, f2(x) == latency (ALMOST DONE)
#  * x axes: wav-length, f(x) = latency (DONE)
#  * x axes: percentil for wav recordings, f1(x) == RTF, f2(x) == 1.0 - teoretical acceptible treshold RTF, f3(x) == 0.6 - practical stricter treshold
#  * x axes: percentil for wav recordings, f1(x) == latency, f2(x) == 0.4s - acceptabel latency treshold
#  * For Google: x axes: percentil for wav recordings, f1(x) == latency, f2(x) == 0.4s - acceptabel latency treshold

# %%
wl_dup, bt, beam, lat_beam, max_active = [], [], beam_range[0], lat_beam_range[0], max_active_range[0]

for wl in wav_len_values:
    back_time = [ rec.backwardlen for rec in user_time_r if 
                 rec.beam == beam and rec.wav_len == wl and
                 rec.lattice_beam == lat_beam and rec.max_active == max_active]
    for btv in back_time:
        wl_dup.append(wl)
        bt.append(btv)
    
plot(wl_dup, bt, '.')    
xlabel('wav len')
ylabel('Backward decoding time ~ Latency')
title('Latency vs wave length.')

# %%
print('Number of wavs %d. Min length %f, Max length %f, Avg length %f' % (len(wav_len_values), min(wav_len_values), max(wav_len_values), sum(wav_len_values) / len(wav_len_values))) 

subplot(1,3,1)
plot(range(len(wav_len_values)), wav_len_values, '+')
ylabel('wav len')
xlabel('wav index')
title('Wave lengths')

subplot(1,3,2)
ylabel('beam values')
title('Forward beam')
bar(range(len(beam_range)), beam_range)
frame = gca()
frame.axes.get_xaxis().set_visible(False)

subplot(1,3,3)
title('Lattice beam values')
ylabel('lattice-beam')
bar(range(len(lat_beam_range)), lat_beam_range)
frame = gca()
frame.axes.get_xaxis().set_visible(False)
# Out:
# Number of wavs 948. Min length 0.400000, Max length 59.808000, Avg length 2.128068

# %%
lat_beam, max_active = lat_beam_range[0], max_active_range[0]
minf, avgf, maxf, werl = [], [], [], []
for beam in beam_range:
    forwardrtf = [ rec.forwardlen / float(rec.wav_len) for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    wers = [ cwer(rec.ins, rec.dl, rec.sub, rec.refer_words) for rec in sys_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    assert len(wers) == 1, 'wer is computed for each setting on all utterances at once-> 1 value'
    werl.append(wers[0])
    minf.append(min(forwardrtf))
    avgf.append(sum(forwardrtf) / float(len(forwardrtf)))
    maxf.append(max(forwardrtf))

fig, ax1 = subplots()
ax1.plot(beam_range, minf, 'g.-.')
ax1.plot(beam_range, avgf, 'b.-.')
ax1.plot(beam_range, [1.0] * len(beam_range), 'b--')
ax1.plot(beam_range, [0.6] * len(beam_range), 'b--')
ax1.plot(beam_range, maxf, 'r.-.')
ax1.set_xlabel('Beam values')
ax1.set_ylabel('Forward RTF')
for tl in ax1.get_yticklabels():
    tl.set_color('b')

ax2 = ax1.twinx()
ax2.plot(beam_range, werl, 'y')
ax2.set_ylabel('WER')
ylim([0, 110])
for tl in ax2.get_yticklabels():
    tl.set_color('y')

title('Forward beam vs forward RTF and WER (TODO: 95% values instead of min, max, avg.)')

# %%
beam, max_active = beam_range[0], max_active_range[0]
minf, avgf, maxf, werl = [], [], [], []
for lat_beam in lat_beam_range:
    back_time = [ rec.backwardlen for rec in user_time_r if rec.beam == beam 
                 and rec.lattice_beam == lat_beam and rec.max_active == max_active]
    wers = [ cwer(rec.ins, rec.dl, rec.sub, rec.refer_words) for rec in sys_time_r if rec.beam == beam 
            and rec.lattice_beam == lat_beam and rec.max_active == max_active]
    assert len(wers) == 1, 'wer is computed for each setting on all utterances at once-> 1 value'
    werl.append(wers[0])
    minf.append(min(back_time))
    avgf.append(sum(back_time) / float(len(back_time)))
    maxf.append(max(back_time))

fig, ax1 = subplots()
ax1.plot(lat_beam_range, minf, 'g.-.')
ax1.plot(lat_beam_range, avgf, 'b.-.')
ax1.plot(lat_beam_range, [0.4] * len(lat_beam_range), 'b--')
# ax1.plot(lat_beam_range, maxf, 'r.-.')
ax1.set_xlabel('Lattice beam values')
ax1.set_ylabel('Backward decoding time ~ Latency')
for tl in ax1.get_yticklabels():
    tl.set_color('b')

ax2 = ax1.twinx()
ax2.plot(lat_beam_range, werl, 'y')
ylim([0, 110])
ax2.set_ylabel('WER')
for tl in ax2.get_yticklabels():
    tl.set_color('y')

title('Backwar lat_beam vs latency and WER (TODO: 95% values instead of min, max, avg.)')

# %%
lat_beam, max_active = lat_beam_range[0], max_active_range[0]
minb, avgb, maxb = [], [], []
for beam in beam_range:
    backwardlen = [ rec.backwardlen for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    minb.append(min(backwardlen))
    avgb.append(sum(backwardlen) / float(len(backwardlen)))
    maxb.append(max(backwardlen))
pl.plot(beam_range, minb, 'g')
pl.plot(beam_range, avgb, 'b')
# pl.plot(beam_range, maxb, 'r')
pl.show()

# %%
beam, max_active = beam_range[2], max_active_range[0]
minf, avgf, maxf = [], [], []
for lat_beam in lat_beam_range:
    forwardrtf = [ rec.forwardlen/ float(rec.wav_len) for rec in user_time_r if rec.beam == beam and rec.lattice_beam == lat_beam
                    and rec.max_active == max_active]
    minf.append(min(forwardrtf))
    avgf.append(sum(forwardrtf) / float(len(forwardrtf)))
    maxf.append(max(forwardrtf))
pl.plot(lat_beam_range, minf, 'g')
pl.plot(lat_beam_range, avgf, 'b')
pl.plot(lat_beam_range, maxf, 'r')
pl.show()

# %%
werv =[ (cwer(rec.ins, rec.dl, rec.sub, rec.refer_words), rec.beam, rec.lattice_beam, rec.max_active) for rec in sys_time_r]

print sorted([(l,b,m,w) for (w,b,l,m) in werv])
# Out:
# [(7.0, 13.0, 2000.0, 19.53125), (7.0, 13.0, 6000.0, 18.110795454545453), (7.0, 13.0, 12000.0, 18.07528409090909), (7.0, 14.0, 2000.0, 19.673295454545453), (7.0, 14.0, 6000.0, 18.25284090909091), (7.0, 14.0, 12000.0, 18.110795454545453), (7.0, 15.0, 2000.0, 19.63778409090909), (7.0, 15.0, 6000.0, 18.25284090909091), (7.0, 15.0, 12000.0, 18.110795454545453), (7.0, 16.0, 2000.0, 19.63778409090909), (7.0, 16.0, 6000.0, 18.25284090909091), (7.0, 16.0, 12000.0, 18.110795454545453), (7.0, 16.5, 2000.0, 19.673295454545453), (7.0, 16.5, 6000.0, 18.217329545454547), (7.0, 16.5, 12000.0, 18.07528409090909), (7.5, 13.0, 2000.0, 19.566761363636363), (7.5, 13.0, 6000.0, 18.110795454545453), (7.5, 13.0, 12000.0, 18.07528409090909), (7.5, 14.0, 2000.0, 19.708806818181817), (7.5, 14.0, 6000.0, 18.25284090909091), (7.5, 14.0, 12000.0, 18.110795454545453), (7.5, 15.0, 2000.0, 19.673295454545453), (7.5, 15.0, 6000.0, 18.25284090909091), (7.5, 15.0, 12000.0, 18.110795454545453), (7.5, 16.0, 2000.0, 19.673295454545453), (7.5, 16.0, 6000.0, 18.25284090909091), (7.5, 16.0, 12000.0, 18.110795454545453), (7.5, 16.5, 2000.0, 19.708806818181817), (7.5, 16.5, 6000.0, 18.217329545454547), (7.5, 16.5, 12000.0, 18.07528409090909), (8.0, 13.0, 2000.0, 19.566761363636363), (8.0, 13.0, 12000.0, 18.07528409090909), (8.0, 14.0, 2000.0, 19.708806818181817), (8.0, 14.0, 6000.0, 18.25284090909091), (8.0, 14.0, 12000.0, 18.217329545454547), (8.0, 15.0, 2000.0, 19.673295454545453), (8.0, 15.0, 6000.0, 18.25284090909091), (8.0, 15.0, 12000.0, 18.217329545454547), (8.0, 16.0, 2000.0, 19.673295454545453), (8.0, 16.0, 6000.0, 18.25284090909091), (8.0, 16.0, 12000.0, 18.217329545454547), (8.0, 16.5, 2000.0, 19.708806818181817), (8.0, 16.5, 6000.0, 18.217329545454547), (8.0, 16.5, 12000.0, 18.181818181818183), (9.5, 13.0, 2000.0, 19.566761363636363), (9.5, 13.0, 6000.0, 18.110795454545453), (9.5, 13.0, 12000.0, 18.07528409090909), (9.5, 14.0, 2000.0, 19.708806818181817), (9.5, 14.0, 6000.0, 18.25284090909091), (9.5, 14.0, 12000.0, 18.217329545454547), (9.5, 15.0, 2000.0, 19.673295454545453), (9.5, 15.0, 6000.0, 18.25284090909091), (9.5, 15.0, 12000.0, 18.217329545454547), (9.5, 16.0, 2000.0, 19.673295454545453), (9.5, 16.0, 6000.0, 19.673295454545453), (9.5, 16.0, 12000.0, 19.673295454545453), (9.5, 16.5, 2000.0, 19.673295454545453), (9.5, 16.5, 6000.0, 19.673295454545453), (9.5, 16.5, 12000.0, 19.673295454545453), (11.5, 13.0, 2000.0, 19.673295454545453), (11.5, 13.0, 6000.0, 19.673295454545453), (11.5, 13.0, 12000.0, 19.673295454545453), (11.5, 14.0, 2000.0, 19.673295454545453), (11.5, 14.0, 6000.0, 19.673295454545453), (11.5, 14.0, 12000.0, 19.673295454545453), (11.5, 15.0, 2000.0, 19.673295454545453), (11.5, 15.0, 6000.0, 19.673295454545453), (11.5, 15.0, 12000.0, 19.673295454545453), (11.5, 16.0, 2000.0, 19.673295454545453), (11.5, 16.0, 6000.0, 19.673295454545453), (11.5, 16.0, 12000.0, 19.673295454545453), (11.5, 16.5, 2000.0, 19.673295454545453), (11.5, 16.5, 6000.0, 19.673295454545453), (11.5, 16.5, 12000.0, 19.673295454545453)]
